# %% [markdown]
# ## Finding Multiples
# Multiples are what you get when you multiply a number by integers.
#
# For example, the first five multiples of 3 are 3, 6, 9, 12, and 15.
#
# Multiples are
#
# Let's write some Python code to find multiples of a number.

# %%
number = 3
howManyMultiples = 5
for n in range(1, howManyMultiples+1): # we need the +1 because range doesn't include the last integer
    print(number * n)

# %% [markdown]
# That printed the first five multiples of 3, but how about some code that will ask for a number and how many multiples.

# %%
number = int(input('Give me a number: '))
howManyMultiples = int(input('How many multiples of that number do you want? '))
print('The first',howManyMultiples,'of',number,'are:')
for n in range(1, howManyMultiples+1):
    print(number * n)

# %% [markdown]
# You now have some code that can print out multiples of a number. Use this code to answer the following two questions:
#
# 1) Find the first 7 multiples of the number 9.

# %% [markdown]
# 2) If every 9th caller to a radio station wins a prize, how many of the first 30 callers will win a prize?

# %% [markdown]
# We can also write some code to find the lowest common multiple of two numbers.

# %%
number1 = int(input('What is the first number? '))
number2 = int(input('What is the second number? '))
# figure out which of the two numbers is larger and store it in the variable lcm
if number2 > number1:
    lcm = number2
else:
    lcm = number1

while(True): # start an infinite loop
    if lcm % number1 == 0 and lcm % number2 == 0: # if the remainder of dividing lcm by number1 and number2 is 0
        print('The lowest common multiple is', lcm) # we have found the LCM, so print it
        break # stop the loop
    else:
        lcm += 1 # add one to the lcm and try again

# %% [markdown]
# Use the above code to solve the following two problems:
#
# 1) If hamburger buns are sold in packages (multiples) of 12 and hamburger patties are sold in packages of 8, how many hamburgers would you need to make in order to not have any buns or patties left over?

# %% [markdown]
# 2) Starting at the beginning of a month, if I go to the grocery store every seven days and my sister goes every four days, on which day of the month will we both go to the grocery store on the same day?
